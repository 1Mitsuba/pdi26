# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img= cv2.imread("imagen.jpg")
img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

fig, axs =plt.subplots(1,4,figsize=(20,5))

axs[0].imshow(img_rgb)
axs[0].set_title("imagen")

fig_img=axs[1].imshow(img_rgb[...,0],cmap="gray")
fig.colorbar(fig_img,ax=axs[1],shrink=0.5)
axs[1].set_title("canal Rojo")

fig_img=axs[2].imshow(img_rgb[...,1],cmap="gray")
fig.colorbar(fig_img,ax=axs[2],shrink=0.5)
axs[2].set_title("canal Verde")

fig_img=axs[3].imshow(img_rgb[...,2],cmap="gray")
fig.colorbar(fig_img,ax=axs[3],shrink=0.5)
axs[3].set_title("canal Azul")

plt.show()

# %%
img_rgb[:3,:3,:]
# Out:
# array([[[81, 53, 91],
#         [81, 53, 91],
#         [81, 53, 91]],
#
#        [[42, 14, 52],
#         [42, 14, 52],
#         [42, 14, 52]],
#
#        [[47, 19, 57],
#         [47, 19, 57],
#         [47, 19, 57]]], dtype=uint8)

# %%
plt.imshow(img_rgb[:80,:80,:])

# %%
cv2.imwrite("imagen.jpg",img_rgb)
plt.imsave("imagen_nueva.jpg",cv2.cvtColor(img_rgb,cv2.COLOR_BGR2RGB))

# %% [markdown]
# EJERCICIO PARA GENERAR UNA IMAGEN

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"]=[10,5]
size_imagen=100
R=np.ones((size_imagen,size_imagen))*25
G=np.ones((size_imagen,size_imagen))*128
B=np.ones((size_imagen,size_imagen))*158

imagen=np.dstack((R,G,B))
imagen=np.array(imagen,dtype=int)

plt.figure()
plt.imshow(imagen)
plt.title("imagen de color: naranja")
plt.show()

# %% [markdown]
# Escala de Grises

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img=cv2.imread("imagen.jpg",cv2.IMREAD_GRAYSCALE)

original=img.dtype

img16bits=np.uint16(img)
img_new=img16bits.dtype
print("profundidad del color :",img_new)
#guardado con cv2
cv2.imwrite("imagen_gris.jpg", img)
#guardado con pyplot
plt.imsave("imagen_gris_plt.jpg", img, cmap="gray")

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.title("iamgen original")
plt.imshow(img,cmap="gray")

plt.subplot(1,2,2)
plt.title("imagen con 16bits")
plt.imshow(img16bits,cmap="gray")
# Out:
# profundidad del color : uint16
