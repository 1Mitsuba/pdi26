# %% [markdown]
# Uso de Cv2 abrir una imagen

# %%
import cv2
import matplotlib.pyplot as plt

img=cv2.imread("depositphotos_306528214-stock-illustration-neon-lines-set-space-pixel.jpg")
plt.imshow(img)
plt.show()
